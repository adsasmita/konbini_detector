# %%
import cv2
import pandas as pd
from PIL import Image

# %%
df = pd.read_csv("data/csv/all_labels.csv",index_col=0)

# %%
df.filename.unique()
# Out:
# array(['family mart_35.606919_139.6680649_240.png',
#        'lawson_35.5347905_139.6346221_240.png',
#        'lawson_35.60585_139.618764_240.png', ...,
#        'lawson_35.730193_139.886202_300.png',
#        'lawson_35.661216_139.783801_300.png',
#        'lawson_35.515185_139.70202_240.png'], dtype=object)

# %%
def draw_boxes(image_name):
    rows = full_labels[full_labels.filename == image_name]
    img = cv2.imread(f'data/img/{image_name}')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    for index, row in rows.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('family mart_35.606919_139.6680649_240.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F9B294A0E80>

# %%
Image.fromarray(draw_boxes('lawson_35.5347905_139.6346221_240.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F9B293D7080>
