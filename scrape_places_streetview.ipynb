# %% [markdown]
# ## Imports

# %%
import googlemaps
import requests
import shutil
#from apiclient.discovery import build
import json
import pandas as pd
import numpy as np
import time
import os


PLACES_API_KEY = 'AIzaSyAWMOrLO_2waaQMAUxJ5tg7dco2AwugWGA'
SV_API_KEY = 'AIzaSyAjUu1XJszobGe0nqWuqIgr715_FTojvxQ'
headings = ['0','60','120','180','240','300']

# places api
#andri-konbini-det1: AIzaSyAWMOrLO_2waaQMAUxJ5tg7dco2AwugWGA
# streetview apis
#andri1: AIzaSyBGcwxByVLO2HkdrJicJ_7hp0oRuNmcqgM
#andri-konbini-det1: AIzaSyAjUu1XJszobGe0nqWuqIgr715_FTojvxQ

# %%
CSV_PATH = 'csv/'
PNG_PATH = 'png/'

if not os.path.exists(CSV_PATH):
    os.makedirs(CSV_PATH)
if not os.path.exists(PNG_PATH):
    os.makedirs(PNG_PATH)
    
coor_dict = {'tokyo': {
            'lat_start':35.56,
            'lat_end':35.82,
            'lon_start':139.55,
            'lon_end':139.92}
            }

city_list = list(coor_dict.keys())

kw_list = ['lawson',
           '7-eleven',
           'family mart']

lat_start = coor_dict['tokyo']['lat_start']
lat_end = coor_dict['tokyo']['lat_end']
lon_start = coor_dict['tokyo']['lon_start']
lon_end = coor_dict['tokyo']['lon_end']

for PATH in [CSV_PATH, PNG_PATH]:
    for kw in kw_list:
        kw_path = os.path.join(PATH,kw)
        if not os.path.exists(kw_path):
            os.makedirs(kw_path)
            print(f'created {kw_path}')
                
print('keywords available:')
for i, kw in enumerate(kw_list):
    print(f'{i}: {kw}')
# Out:
# keywords available:
# 0: lawson
# 1: 7-eleven
# 2: family mart

# %%
#radius = '2500'
keytype = 'convenience_store'
keyword = '7-eleven'
rankby = 'distance'
fov = 120
pitch = 5
headings = ['0','60','120','180','240','300']

i = 0
for lat in np.arange(lat_start, lat_end, 0.04):
    for lon in np.arange(lon_start, lon_end, 0.04):
 
        rows = [] #initialize array
        r = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?" \
                        #+f"radius={radius}&" \
                        +f"type={keytype}&" \
                        +f"keyword={keyword}&" \
                        +f"location={lat},{lon}&" \
                        +f"rankby={rankby}&" \
                        +f"key={PLACES_API_KEY}")
        text = r.content.decode('utf-8')
        data = json.loads(text)
        results = data['results']
        for result in results:
            la, lo = result['geometry']['location'].values()

            for heading in headings:     
                r = requests.get(f"https://maps.googleapis.com/maps/api/streetview?size=640x640&" \
                                +f"location={la},{lo}&" \
                                +f"fov={fov}&" \
                                +f"heading={heading}&" \
                                +f"pitch={pitch}&" \
                                +f"key={SV_API_KEY}", stream=True)
                i += 1
                
                out_fname = f"png/{keyword}/{keyword}_{la}_{lo}_{heading}.png"
                with open(os.path.join(out_fname), 'wb') as out_file:
                    shutil.copyfileobj(r.raw, out_file)
                if i%100 ==0:
                        print(f"image saved: {i}")


        # if the result has more than 1 page, append more results
        while 'next_page_token' in data.keys():
            next_page_token = data['next_page_token']
            time.sleep(2) #wait 2 second for google activating token
            r = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?" \
                            +f"pagetoken={next_page_token}&" \
                            +f"key={PLACES_API_KEY}")
            text = r.content.decode('utf-8')
            data = json.loads(text)
            results = data['results']

            for result in results:
                la, lo = result['geometry']['location'].values()

                for heading in headings:     
                    r = requests.get(f"https://maps.googleapis.com/maps/api/streetview?size=640x640&" \
                                    +f"location={la},{lo}&" \
                                    +f"fov={fov}&" \
                                    +f"heading={heading}&" \
                                    +f"pitch={pitch}&" \
                                    +f"key={SV_API_KEY}", stream=True)
                    
                    i += 1
                    out_fname = f"png/{keyword}/{keyword}_{la}_{lo}_{heading}.png"
                    with open(os.path.join(out_fname), 'wb') as out_file:
                        shutil.copyfileobj(r.raw, out_file)
                    
                    if i%100 ==0:
                        print(f"image saved: {i}")
# Out:
# image saved: 100
# image saved: 200
# image saved: 300
# image saved: 400
# image saved: 500
# image saved: 600
# image saved: 700
# image saved: 800
# image saved: 900
# image saved: 1000
# image saved: 1100
# image saved: 1200
# image saved: 1300
# image saved: 1400
# image saved: 1500
# image saved: 1600
# image saved: 1700
# image saved: 1800
# image saved: 1900
# image saved: 2000
# image saved: 2100
# image saved: 2200
# image saved: 2300
# image saved: 2400
# image saved: 2500
# image saved: 2600
# image saved: 2700
# image saved: 2800
# image saved: 2900
# image saved: 3000
# image saved: 3100
# image saved: 3200
# image saved: 3300
# image saved: 3400
# image saved: 3500
# image saved: 3600
# image saved: 3700
# image saved: 3800
# image saved: 3900
# image saved: 4000
# image saved: 4100
# image saved: 4200
# image saved: 4300
# image saved: 4400
# image saved: 4500
# image saved: 4600
# image saved: 4700
# image saved: 4800
# image saved: 4900
# image saved: 5000
# image saved: 5100
# image saved: 5200
# image saved: 5300
# image saved: 5400
# image saved: 5500
# image saved: 5600
# image saved: 5700
# image saved: 5800
# image saved: 5900
# image saved: 6000
# image saved: 6100
# image saved: 6200
# image saved: 6300
# image saved: 6400
# image saved: 6500
# image saved: 6600
# image saved: 6700
# image saved: 6800
# image saved: 6900
# image saved: 7000
# image saved: 7100
# image saved: 7200
# image saved: 7300
# image saved: 7400
# image saved: 7500
# image saved: 7600
# image saved: 7700
# image saved: 7800
# image saved: 7900
# image saved: 8000
# image saved: 8100
# image saved: 8200
# image saved: 8300
# image saved: 8400
# image saved: 8500
